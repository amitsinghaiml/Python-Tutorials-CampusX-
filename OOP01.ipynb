# %% [markdown]
# opp - object orentated programming

# %%
L = [1,2,3,4]

L.upper()       # upper function does not works on list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 L = [1,2,3,4]
# ----> 3 L.upper()       # upper function does not works on list
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'

s.append('x')   # append will not work in a string 


# in the both output we can see pyton refer the list and string as an (((object)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 s = 'hello'
# ----> 3 s.append('x')   # append will not work in a string
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# "EVERYTHING IN PYTHON IS AN OBJECT"

# %% [markdown]
# WHAT IS AN OBJECT ??
#
# WHAT IS OOP?

# %% [markdown]
# OOP ---> CLASS +  POLYMORPHISM + ENCAPSULAYION + INHERITANCE + ABSTRACTION+OBJECT

# %% [markdown]
# CLASS (CLASS IS BLUE PRINT )

# %%
L = [1,2,3]
type(L)
# Out:
# list

# %%
print(type(L))
# Out:
# <class 'list'>

# %% [markdown]
# how to create an obejct

# %%
# syntax to create an object 

# object name = clasname()

# %%
# object literal 
L = [1,2,3]  # we made object like this

# %%
L = list()

# %%
# PASCAL CASE 

HelloWorld

# %% [markdown]
# making class
#
# 1. built in classes
#
# 2. user defined classes

# %%
class Atm:
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.pin = ''  # constructor is a special function , we will not need to call it once we will make an object of that class the function will automatically run
        self.balance = 0
        self.menu()           
        print('mai to execute ho gya ')
        
    def  menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self_balance = user_balance
        
        print('pin created succesfully ')
        self.menu()
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.pin
            print('pin change succesful')
            self.menu()
        else:
            print('wrong try again')
            self.menu()
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.pin:
            print('your balance is',self.balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print('withdrawl is succesful balance is',self.balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')
            
        self.menu()

# %% [markdown]
# function that are made inside of class is called ((method))
#
# and the function that are made outside of class that are independent of class is called ((function))

# %% [markdown]
# makeing object

# %%
obj = Atm()

# %%
L = [1,2,3,4]
len(L)     # len is a Function bcoz it is outside of list class
# Out:
# 4

# %%
L.append(5)  # append is a method  becoz it is inside of list class we can verify it by writing L follwed by a dot(.)
L
# Out:
# [1, 2, 3, 4, 5, 5]

# %% [markdown]
# MAGIC METHOD

# %% [markdown]
# Magic method ----> special method---->super power     __name__  __init__

# %%
class temp:
    
    def __init__(self):
        print('hello')
        
obj = temp()
# Out:
# hello

# %% [markdown]
# All the things that we have to do automatically without depending on the user such as :
#
# 1. connecting to internet ...
#
# 2. connecting to database ....
#
# all the things comes under constructor

# %% [markdown]
# SELF
#
# self is just an object that we give input
#
# id(self) == id(object)

# %%
3/4*1/2  # we need its answer in fraction
# Out:
# 0.375

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.deno = y

# %%
fr1 = fraction(2,3)

# %%
print(fr1) # python dont know what is the fraction it just know that it is a function stored at specific location

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.deno = y 
        
    def __str__(self):             #  Here, __str__() tells Python what text should be shown when you print an object
        return 'hogya mera'

# %%
st3 = fraction(4,4)

# %%
print(st3)
# Out:
# hogya mera

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.den = y 
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)     #  .format() fills those {} placeholders with values.
             
               # The {} are empty placeholders

# %%
fr1 = fraction(4,5)

f3 = fraction(7,8)

# %%
print(fr1)

print(f3)
# Out:
# 4/5
# 7/8

# %%
print(fr1 + f3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(fr1 + f3)
#
# TypeError: unsupported operand type(s) for +: 'fraction' and 'fraction'

# %% [markdown]
# 3rd magic method

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.den = y 
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num * other.den + self.den *other.num
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)

# %%
fr1 = fraction(3,5)
fr2 = fraction(7,8)

# %%
print(fr1 + fr2 )
# Out:
# 59/40

# %% [markdown]
# 4 th  __sub__ magic method for subtraction(-)

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.den = y 
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num * other.den + self.den *other.num
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self,other):
            new_num = self.num * other.den - self.den *other.num
            new_den = self.den * other.den
            
            return '{}/{}'.format(new_num,new_den)

# %%
fr1 = fraction(3,5)
fr2 = fraction(7,8)

# %%
print(fr1 - fr2 )
# Out:
# -11/40

# %% [markdown]
# 5th __mul__ magic method for multiplication

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.den = y 
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num * other.den + self.den *other.num
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self,other):
            new_num = self.num * other.den - self.den *other.num
            new_den = self.den * other.den
            
            return '{}/{}'.format(new_num,new_den)
        
    def __mul__(self,other):
                new_num = self.num  * other.num
                new_den = self.den * other.den
                 
                return '{}/{}'.format(new_num,new_den)

# %%
fr1 = fraction(4,5)
fr2 = fraction(6,7)

# %%
print(fr1*fr2)
# Out:
# 24/35

# %% [markdown]
# 6th __truediv__ magic method

# %%
class fraction:
    
    # make constructor
    def __init__(self,x,y):        # the constructor which need an input is called parameterized constructor
        self.num = x
        self.den = y 
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num * other.den + self.den *other.num
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self,other):
            new_num = self.num * other.den - self.den *other.num
            new_den = self.den * other.den
            
            return '{}/{}'.format(new_num,new_den)
        
    def __mul__(self,other):
                new_num = self.num  * other.num
                new_den = self.den * other.den
                 
                return '{}/{}'.format(new_num,new_den) 
            
    def __truediv__(self,other):
                    new_num = self.num *other.den
                    new_den = self.den * other.num
                     
                    return '{}/{}'.format(new_num,new_den)
            
    def convert_to_decimal(self):
        return self.num/self.den

# %%
fr1 = fraction(2,2)
fr2 = fraction(3,4)

# %%
print(fr1/fr2 )
# Out:
# 8/6

# %%
print(fr1 + fr2 )
print(fr1 - fr2 )
print(fr1 * fr2 )
# Out:
# 14/8
# 2/8
# 6/8

# %%
fr1 = fraction(4,5)
fr1.convert_to_decimal()
# Out:
# 0.8
