# %%
##text/string
print("hello world")
# Out:
# hello world

# %%
# Integers
print(8)
# Out:
# 8

# %%
#decimal
print(8.44)
# Out:
# 8.44

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#complex
print(4+3j)
# Out:
# (4+3j)

# %%
#tuple
print((1,2,3,4,))
# Out:
# (1, 2, 3, 4)

# %%
#list
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#dictionary
print({'name':'nitish','gennder':'male','weight':70})
# Out:
# {'name': 'nitish', 'gennder': 'male', 'weight': 70}

# %%
#type (define the type of function jut put the fn run it and it will show the type of fn )
type({1,2,3})
# Out:
# set

# %%
# Variables
name="amit" 
print(name,end='-')
a=("ajit")
b=("janu")
print(a + b)
# Out:
# amit-ajitjanu

# %%
#dynamic typing (python)
a=4
#static typing(c++,java)
int a=4

# %%
#dynamic binding(python support)
a=5 
print(a)
a='amit'
print(a)
b=5
print(b)
# Out:
# 5
# amit
# 5

# %%
#static binding
int a=5

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c,)
# Out:
# 5 5 5

# %% [markdown]
# comments

# %%
# this is a comment 
a=4
b=3
# second comment
print(a+b)

# %% [markdown]
# keywords

# %% [markdown]
# identifiers

# %%
#udentifiers
# You can't start with a digit
name="amit"
print(name)
#you can use special chars -> _
_='ajit'
print(_)
# identifiers can not be keywords
# Out:
# amit
# ajit

# %% [markdown]
# user input

# %%
# static software vs dynmaic software
input()
# Out:
# 'hello'

# %%
input('enter email')
# Out:
# ''

# %%
 # Take input from user and store them in variables 
fnum=input('enter first number')
 snum=input('enter second number')
 # add the 2 variables 
 print(fnum,snum)
 
 result=fnum+snum
 # print the result
 print(result)
# Out:
# 67 69
# 6769

# %% [markdown]
# Type conversion

# %%
# Implicit and explicit
print(5+5.6)
print(type(5),type(5.6))

print(4+'4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2 print(5+5.6)
#       3 print(type(5),type(5.6))
# ----> 5 print(4+"4")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Explicit

# %%
# Explicit
# str--> int
int('4')
type(int('4'))
# Out:
# int

# %% [markdown]
# Literals

# %%
a=0b1010 #binary literal
b=100    # decimal literal
c=0o310  # Octal literal
d=0x12c  # Hexadecimal Literal

#float Literal 
float_1=10.5
float_2=1.5e2   # 1.5*10^2
float_3=1.5e-3  # 1.5*10^-3


#complex Literal
x= 3.14j

print(a,b,c,)
print(float_1,float_2)
print(x,x.imag,x.real)

# %%
string='this is python'
strings="this is python"
char="C"
multiline_str="""This is a multiliner string more than one line code""""
unicode =u"\U001f600\U0001J43"
raw_str=r"raw \n string"

print(string)
print(string)
print(char)
print(multiline_str)
print(unicode)
print(craw_str)
# Out:
#   Cell In[55], line 4
#     multiline_str="""This is a multiliner string more than one line code""""
#                                                                            ^
# SyntaxError: unterminated string literal (detected at line 4)

# %% [markdown]
# boolean
# (treat true as 1
#        false as 0 )

# %%
a=True+4
b=False+10

print("a",a)
print("b",b)
# Out:
# a 5
# b 10

# %% [markdown]
# None

# %%
k=None
a=4
b=5
print("execute code")
# Out:
# execute code
