# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# - in class diagram if two class are joined by a rhombus (kite) it is a sign of aggregation

# %% [markdown]
# ### Aggregation(Has-A relationship)

# %%
# example 

class Customer:
    
    def __init__(self,name,gender,address):                 # need 3 thing name ,gender , ((address))
        self.name = name 
        self.gender = gender 
        self.address = address
        
    def print_address(self):
        print(self.address.city,self.address.pin,self.address.state)
        
class Address:                                         # we made seprate class for address bcoz the address is a complex entity
    
    def __init__(self,city,pin,state):
        self.city = city 
        self.pin = pin 
        self.state = state
        
add1 = Address('kalyan',421103,'maharashtra')                  # first we made obj of class address and then the object of class customer and then we gave the object of class adress as an input object to class customer
cust = Customer('amit','male',add1)                            # this is called aggregation , communcation of class between them selfs
        
cust.print_address()
# Out:
# kalyan 421103 maharashtra

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.__city,self.address.pin,self.address.state)

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state



add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


# what about private attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 25
#      22 add1 = Address('gurgaon',122011,'haryana')
#      23 cust = Customer('nitish','male',add1)
# ---> 25 cust.print_address()
#      28 # what about private attribute
#
# Cell In[7], line 10, in Customer.print_address(self)
#       9 def print_address(self):
# ---> 10   print(self.address.__city,self.address.pin,self.address.state)
#
# AttributeError: 'Address' object has no attribute '_Customer__city'

# %% [markdown]
# while aggregation we cannot access the hidden variable

# %% [markdown]
# but we can print is we write  geter

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):                              # geter 
      return self.__city
      

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


# what about private attribute
# Out:
# gurgaon 122011 haryana

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)
    
    
  def edit_profile(self, new_name,new_city,new_pin, new_state):
      self.name = new_name
      self.address.edit_address(new_city,new_pin,new_state)
       

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state
      
  def edit_address(self,new_city,new_pin, new_state):
      self.__city = new_city
      self.pin = new_pin
      self.state = new_state
        
        

  def get_city(self):
      return self.__city
                                                             # geter 
      
#-------------------------------------------------------------------------------
add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


cust.edit_profile('amit','mumbai',101001,'maharastra')
cust.print_address()


# what about private attribute
# Out:
# gurgaon 122011 haryana
# mumbai 101001 maharastra

# %% [markdown]
# ### Inheritance
#
# - What is inheritance
# - Example
# - What gets inherited?

# %%
 # Example 
 
class user:
     
    def __init__(self):
        self.name = 'amit'
         
    def login(self):
        print('login')
        
class student:
    
    def __init__(self):
        self.rollno = 100
        
    def enroll(self):
        print('enroll into the course')

# %%
 # Example 
 
class user:                 # parent class
    
     
    def __init__(self):
        self.name = 'amit'
        self.gender = 'male'
         
    def login(self):
        print('login')
        
class student(user):          # child class
     
    def __init__(self):
        self.rollno = 100
        
    def enroll(self):
        print('enroll into the course')    
        
        
        
U = user()
s = student()

print(U.name)
print(U.gender)
print(s.enroll)
print(s.rollno)
# Out:
# amit
# male
# <bound method student.enroll of <__main__.student object at 0x00000193D03A1C10>>
# 100

# %%
 # Example 
 
class user:                 # parent class
    
     
    def __init__(self):
        self.name = 'amit'
        self.gender = 'male'
         
    def login(self):
        print('login')
        
class student(user):          # child class
     
                              # removed constructor        
    def enroll(self):
        print('enroll into the course')    
        
        
        
U = user()
s = student()

print(s.name)
print(s.gender)
print(s.enroll)                               # we can only use parent constructor when in our class there is no constructor
# Out:
# amit
# male
# <bound method student.enroll of <__main__.student object at 0x00000193D02FFC50>>

# %% [markdown]
# ### what get inherited
#
# - constructor
# - non private attributes  (jo hidden nahi hai)
# - non private

# %% [markdown]
# - between two class they are connected by a triangle it is sign of inheritance , and the arrow head points to the parent class

# %%
class phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("buying a phone")
        
class smartphone(phone):
    pass



S = smartphone(2000,"apple",13)
# Out:
# inside phone constructor

# %%
S.price
S.buy()
# Out:
# buying a phone

# %%
class phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.price = price
        self.brand = brand
        self.camera = camera
        
        
class smartphone(phone):
    def __init__(self,os,ram):
        self.os = os
        self.ram = ram
        print("inside of samrtphone constructor")
    



S = smartphone("Android",2)
S.ram
# Out:
# inside of samrtphone constructor
# 2

# %%
# child access private member of the class 

class phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def __show(self):
        print(self.__price)
        
class smartphone(phone):
    pass



S = smartphone(2000,"apple",13)
print(S.brand)
print(S.__price)                 # child class object cannot access private data

S.__show()                   # child class canoot even access private methods
# Out:
# inside phone constructor
# apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 20
#      18 S = smartphone(2000,"apple",13)
#      19 print(S.brand)
# ---> 20 print(S.__price)                 # child class object cannot access private data
#      22 S.__show()                   # child class canoot even access private methods
#
# AttributeError: 'smartphone' object has no attribute '__price'

# %%
# Example

class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)                    # here self.var1 = 100 is differnet from var1 = 200
# Out:
# class A : 100

# %%
# Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called
# Out:
# buying a smartphone

# %% [markdown]
# ## Super keyword

# %% [markdown]
# always inside class

# %%
# Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
        # syntax to call parent ka buy method
        
        super().buy()
        
    
        
        
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called
# Out:
# buying a smartphone
# buying a phone

# %%
# Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
        # syntax to call parent ka buy method
        
        
        
    
        
        
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called 

# Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
        # syntax to call parent ka buy method
        
        super().buy()
        
    
        
        
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called 

 # Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
        # syntax to call parent ka buy method
        
        
               
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called 

s.super().buy()               # we cannot appply super keyword outside of class
# Out:
# buying a smartphone
# buying a smartphone
# buying a phone
# buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 91
#      87 s.buy()
#      89  # if parent and and son class both have same method son method will be called
# ---> 91 s.super().buy()               # we cannot appply super keyword outside of class
#
# AttributeError: 'smartphone' object has no attribute 'super'

# %%
# Method  overriding 

class phone:
    
    def __init__(self,price,brand,camera):
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('buying a phone')
        
class smartphone(phone):
    
    def buy(self):
        print('buying a smartphone')
        
        
        # syntax to call parent ka buy method
        
        print(super().brand)    # we  cannot access attribute using super 
        
    
        
        
s = smartphone(2000,'apple',13)

s.buy() 

 # if parent and and son class both have same method son method will be called
# Out:
# buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 28
#      21         print(super().brand)    # we  cannot access attribute using super
#      26 s = smartphone(2000,'apple',13)
# ---> 28 s.buy()
#      30  # if parent and and son class both have same method son method will be called
#
# Cell In[10], line 21, in smartphone.buy(self)
#      16 print('buying a smartphone')
#      19 # syntax to call parent ka buy method
# ---> 21 print(super().brand)
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %% [markdown]
# ### parent class cannot access child class but child class can access parent  class

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class parent:
    
    def __init__(self):
        self.__num = 100
        
    def show(self):
        print("parent:",self.__num)
        
class child(parent):
    def __init__(self):
        super().__init__()
        self.__var = 10
    
    def show(self):
        print("child",self.__var)
        
        
son = child()
son.show()
# Out:
# child 10

# %% [markdown]
# ### Type of inheritace
#
# - single inheritance (father ------>son )
# - multilevel         (......dada -->father --->son----son ka son......)
# - Hierarchical       (multiple children )
# - multiple inheritance (Diamond problem)  (father +mother ---->son)
# - hybrid inheritance  {single + multiple + hierarchical}

# %%
# single  inheritance

class phone:
    def __init__(self,price ,brand,camera):
        print("Inside phone camera")
        self.__price = price 
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("buying a phone")
        
class smartphone(phone):
    pass


smartphone(1000,'apple',"13px").buy()
# Out:
# Inside phone camera
# buying a phone

# %%
# MULTILEVEL 

class product:
    
    def review(self):
        print("product customers review")
        
class phone(product):
        
    def __init__(self,price ,brand,camera):
        print("Inside phone camera")
        self.__price = price 
        self.brand = brand
        self.camera = camera
        
    def buy(self):
            print("buying a phone")
        
class Smartphone(phone):
    pass




s = Smartphone(1000,'apple',"13px")
s.review()
s.brand
s.buy()
# Out:
# Inside phone camera
# product customers review
# buying a phone

# %%
# the diamond problem

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):                       # when we call obj.m1() there is same code in prents class therefore this leads to code overriding and we get redirect to the child class this occour infinite number of times leads to breaking of code
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[16], line 18
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# Cell In[16], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# Cell In[16], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
#     [... skipping similar frames: C.m1 at line 15 (2974 times)]
#
# Cell In[16], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
class Shape:
   
    def area(self,radius):                # if one input is given
        return 3.14*radius*radius
    
    def area(self,l,b):                   # if two input is given
        return l*b
    
    # this is method overloading
    
    # python do not allow method overloading
    
    
    
S = Shape()
S.area(2)  # the first method is not working only the second one is working
S.area(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 16
#       9     # this is method overloading
#      10
#      11     # python do not allow method overloading
#      15 S = Shape()
# ---> 16 S.area(2)  # the first method is not working only the second one is working
#      17 S.area(3,4)
#
# TypeError: Shape.area() missing 1 required positional argument: 'b'

# %%
class Shape:
   
    def area(self,a,b=0):
        if b == 0:
            return 3.14*a*a
        else:
            return 3.14*a*b
        
        

    
    
S = Shape()
S.area(2)  # the first method is not working only the second one is working
S.area(4,1)
# Out:
# 12.56

# %%
# operator overloading -----> magic methods

'hello' + 'world'
# Out:
# 'helloworld'

# %%
4 + 5
# Out:
# 9

# %%
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Abstraction
# (hidden)

# %%
from abc import ABC , abstractmethod
class BankApp(ABC):                       # it become abstract class when it inherit (ABC) 
    
    def database(self):
        print('connected to database')
    
    @abstractmethod   
    def security(self):          # abstract method
        pass

# %%
class MobileApp(BankApp):
    
    def mobile_login(self):
        print('login into mobile')

# %%
B = MobileApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 B = MobileApp()
#
# TypeError: Can't instantiate abstract class MobileApp without an implementation for abstract method 'security'

# %%
class MobileApp(BankApp):
    
    def mobile_login(self):
        print('login into mobile')
    
    
    def security(self):
        print('mobile safety')

# %%
mob = MobileApp()

# %%
mob.mobile_login()
# Out:
# login into mobile

# %%
mob.BankApp()      we cannot amke object of this class
# Out:
#   Cell In[2], line 1
#     mob.BankApp()      we cannot amke object of this class
#                        ^
# SyntaxError: invalid syntax
