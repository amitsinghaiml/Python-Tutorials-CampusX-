# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship)

# %%
# example 

class Customer:
    
    def __init__(self,name,gender,address):                 # need 3 thing name ,gender , ((address))
        self.name = name 
        self.gender = gender 
        self.address = address
        
    def print_address(self):
        print(self.address.city,self.address.pin,self.address.state)
        
class Address:                                         # we made seprate class for address bcoz the address is a complex entity
    
    def __init__(self,city,pin,state):
        self.city = city 
        self.pin = pin 
        self.state = state
        
add1 = Address('kalyan',421103,'maharashtra')                  # first we made obj of class address and then the object of class customer and then we gave the object of class adress as an input object to class customer
cust = Customer('amit','male',add1)                            # this is called aggregation , communcation of class between them selfs
        
cust.print_address()
# Out:
# kalyan 421103 maharashtra

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.__city,self.address.pin,self.address.state)

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state



add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


# what about private attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 25
#      22 add1 = Address('gurgaon',122011,'haryana')
#      23 cust = Customer('nitish','male',add1)
# ---> 25 cust.print_address()
#      28 # what about private attribute
#
# Cell In[7], line 10, in Customer.print_address(self)
#       9 def print_address(self):
# ---> 10   print(self.address.__city,self.address.pin,self.address.state)
#
# AttributeError: 'Address' object has no attribute '_Customer__city'

# %% [markdown]
# while aggregation we cannot access the hidden variable

# %% [markdown]
# but we can print is we write  geter

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):                              # geter 
      return self.__city
      

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


# what about private attribute
# Out:
# gurgaon 122011 haryana

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)
    
    
  def edit_profile(self, new_name,new_city,new_pin, new_state):
      self.name = new_name
      self.address.edit_address(new_city,new_pin,new_state)
       

  
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state
      
  def edit_address(self,new_city,new_pin, new_state):
      self.__city = new_city
      self.pin = new_pin
      self.state = new_state
        
        

  def get_city(self):
      return self.__city
                                                                     # geter 
      
#-------------------------------------------------------------------------------
add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()


cust.edit_profile('amit','mumbai',101001,'maharastra')
cust.print_address()


# what about private attribute
# Out:
# gurgaon 122011 haryana
# mumbai 101001 maharastra

# %% [markdown]
# ### Inheritance
#
# - What is inheritance
# - Example
# - What gets inherited?
