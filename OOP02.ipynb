# %% [markdown]
# Write OOP classes to handle the following scenarios:
#
#
# A user can create and view 2D coordinates
#
# A user can find out the distance between 2 coordinates
#
# A user can find find the distance of a coordinate from origin
#
# A user can check if a point lies on a given line
#
# A user can find the distance between a given 2D point and a given line

# %%
class point:
    
    def __init__(self,x,y):  # init magic fn and x ,y are the input should be given while executing the code 
        self.x_cord = x
        self.y_cord = y
        
    def __str__(self):
        return ' <{},{}>'.format(self.x_cord,self.y_cord)    #A user can create and view 2D coordinates
     
    def euclidean_distance(self,other):
        return ((self.x_cord - other.x_cord)**2 + (self.y_cord - other.y_cord)**2)**0.5   # 2nd  topic 
    
    
    def distance_from_origin(self):
        return ((self.x_cord)**2 + (self.y_cord)**2  )**0.5
    
#   def distance_from_origin(self):
#        return self.euclidean_distance(other(0,0))          -------> this will also work

# %%
p1 = point(4,5)

# %%
print(p1)
# Out:
#  <4,5>

# %%
p2 = point(4,7)

# %%
p1.euclidean_distance(p2)
# Out:
# 2.0

# %%
p1 = point(6,0)
p1.distance_from_origin()
# Out:
# 6.0

# %% [markdown]
# A user can check if a point lies on a given line

# %%
class point:
    
    def __init__(self,x,y):  # init magic fn and x ,y are the input should be given while executing the code 
        self.x_cord = x
        self.y_cord = y
        
    def __str__(self):
        return ' <{},{}>'.format(self.x_cord,self.y_cord)    #A user can create and view 2D coordinates
     
    def euclidean_distance(self,other):
        return ((self.x_cord - other.x_cord)**2 + (self.y_cord - other.y_cord)**2)**0.5   # 2nd  topic 
    
    
    def distance_from_origin(self):
        return ((self.x_cord)**2 + (self.y_cord)**2  )**0.5
    
#   def distance_from_origin(self):
#        return self.euclidean_distance(other(0,0))          -------> this will also work 

class line:
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
            
    def __str__(self):
        return '{}x +{}y + {} = 0'.format(self.A,self.B,self.C)

# %%
l1 = line(1,1,1)

# %%
print(l1)
# Out:
# 1x +1y + 1 = 0

# %% [markdown]
# a user can check if a point liw on the line or not

# %%
# if a point lie on the line then the eqn of line becomes zero 
class point:
    
    def __init__(self,x,y):  # init magic fn and x ,y are the input should be given while executing the code 
        self.x_cord = x
        self.y_cord = y
        
    def __str__(self):
        return ' <{},{}>'.format(self.x_cord,self.y_cord)    #A user can create and view 2D coordinates
     
    def euclidean_distance(self,other):
        return ((self.x_cord - other.x_cord)**2 + (self.y_cord - other.y_cord)**2)**0.5   # 2nd  topic 
    
    
    def distance_from_origin(self):
        return ((self.x_cord)**2 + (self.y_cord)**2  )**0.5
    
#   def distance_from_origin(self):
#        return self.euclidean_distance(other(0,0))          -------> this will also work 

class line:
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
            
    def __str__(self):
        return '{}x +{}y + {} = 0'.format(self.A,self.B,self.C)
        
    
    def point_on_line(line,point):
        if line.A*point.x_cord + line.B*point.y_cord + line.C == 0:
            return "lies on the line "
        else:
            return "does not lie on the line "

# %%
l1 = line(1,1,-2)
p1 = point(1,1)
print(l1)
print(p1)
# Out:
# 1x +1y + -2 = 0
#  <1,1>

# %%
l1.point_on_line(p1)
# Out:
# 'lies on the line '

# %% [markdown]
# A user can find the distance between a given 2D point and a given line

# %%
# if a point lie on the line then the eqn of line becomes zero 
class point:
    
    def __init__(self,x,y):  # init magic fn and x ,y are the input should be given while executing the code 
        self.x_cord = x
        self.y_cord = y
        
    def __str__(self):
        return ' <{},{}>'.format(self.x_cord,self.y_cord)    #A user can create and view 2D coordinates
     
    def euclidean_distance(self,other):
        return ((self.x_cord - other.x_cord)**2 + (self.y_cord - other.y_cord)**2)**0.5   # 2nd  topic 
    
    
    def distance_from_origin(self):
        return ((self.x_cord)**2 + (self.y_cord)**2  )**0.5
    
#   def distance_from_origin(self):
#        return self.euclidean_distance(other(0,0))          -------> this will also work 

class line:
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
            
    def __str__(self):
        return '{}x +{}y + {} = 0'.format(self.A,self.B,self.C)
        
    
    def point_on_line(line,point):
        if line.A*point.x_cord + line.B*point.y_cord + line.C == 0:
            return "lies on the line "
        else:
            return "does not lie on the line "
        
    def shortes_distance(line,point):
        return abs(line.A*point.x_cord +line.B*point.y_cord + line.C)/(line.A**2 + line.B**2)**0.5

# %%
p1 = point(1,1)
l1 = line(2,0,0)
print(l1)
print(p1)
# Out:
# 2x +0y + 0 = 0
#  <1,1>

# %%
l1.shortes_distance(p1)
# Out:
# 1.0

# %% [markdown]
# two line segment intersect or not
#
# input 2 line object

# %% [markdown]
# how object access attributes

# %%
class person:
    def __init__(self,name_input,country_input):
        self.name = name_input
        self.country = country_input
        
    def greet(self):
        if self.country == 'india':
            print('namste',self.name)
        else:
            print('hello',self.name)

# %%
# how to access attributes
P = person('amit','india')

# %%
# how to access methods
P.country
P.name
P.greet()   # for accessing methods type bracket
# Out:
# namste amit

# %%
# what is i try to access non - existent attributes
P.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 # what is i try to access non - existent attributes
# ----> 2 P.gender
#
# AttributeError: 'person' object has no attribute 'gender'

# %% [markdown]
# Attributes creation from outside of the class

# %%
P.gender = 'male'

# %%
P.gender

# %% [markdown]
# Reference Variables
#
# 1. Reference variables hold the objects
#
# 2. We can create objects without reference variable as well
#
# 3. An object can have multiple reference variables
#
# 4. Assigning a new reference variable to an existing object does not create a new object

# %%
# object without reference 

class person:
    def __init__(self):
        self.name = 'amit'
        self.gender = 'male'

p = person()                    # from start we were saying that p is an object of class but noo

# %%
# object without reference 

class person:
    def __init__(self):
        self.name = 'amit'
        self.gender = 'male'

person()                        # when we call person an object is get created by that and that object is  stored at p , p is just a variable name who have address of memory

# %%
p = person()
q = p

# %%
print(id(p))
print(id(q))

# %%
print(p.name)
print(q.name)

# %%
q.name = 'ajit'

# %%
print(q.name)
print(p.name)

# %% [markdown]
# Passs by refrence

# %%
class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender =  gender 
        
# outside of the class ----> function
def greet(person):
    print('hi my name is',person.name,'and i am',person.gender)
    

p = person('amit','male')                 # this is the first time the input of function is an object of class
greet(p)
                                          # that function returns the object

# %%
class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender =  gender 
        
# outside of the class ----> function
def greet(person):
    print(id(person))
    print('hi my name is',person.name,'and i am',person.gender)
    

p = person('amit','male')    
print(id(p))
greet(p)

# %%
class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender =  gender 
        
# outside of the class ----> function
def greet(person):
    print(id(person))
    person.name = 'ajit'
    print(person.name)
    

p = person('amit','male')    
print(id(p))
greet(p)
print(p.name)

# %%
class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender =  gender 
        
# outside of the class ----> function
def greet(person):
    person.name = 'ajit'
    
    

p = person('amit','male')    
print(id(p))
greet(p)
print(id(p))

# %%
class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender =  gender 
        
# outside of the class ----> function
def greet(person):
    person.name = 'ajit'
    return person
    
    

p = person('amit','male')    
print(id(p))
p1 = greet(p)
print(id(p1))                     # here even though we make chnages in the function and also gave it a new variable name its address does not chnage becuse...

                                  # MEMORY ADDRESS DOES NOT CHANGE IT MEANS THAT THE FUNCTION IS MUTABLE SO EVEN THOUGH WE MADE CHANGES PYTHON ALLOWS IT AND STORED AND SAME MEMORY LOCATION HENCE id(p) == id(p1)
                                   
                                  # the objects in python are MUTABLE BY DEFAULT

# %% [markdown]
# ENCAPSULATION

# %%
# instance  var ----> python tutor

class person:
    
    def __init__(self,name_input,country_input):
        self.name = name_input
        self.country = country_input
        
p1 = person('amit','india')
p2 = person('alex','london')
    
                              # the variable name and country holds two values
                              # so instance variable is a special var whose  values is differnt depending upon the object

# %%
p1.name

# %%
p2.name

# %%
class Atm:
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.pin = ''  # constructor is a special function , we will not need to call it once we will make an object of that class the function will automatically run
        self.balance = 0
        self.menu()           
        print('mai to execute ho gya ')
        
    def  menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self_balance = user_balance
        
        print('pin created succesfully ')
        self.menu()
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.pin
            print('pin change succesful')
            self.menu()
        else:
            print('wrong try again')
            self.menu()
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.pin:
            print('your balance is',self.balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print('withdrawl is succesful balance is',self.balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')
            
        self.menu()

# %%
obj = Atm()

# %%
obj.change_pass()
obj.balance = 'heeehee'

# %%
obj.user_withdraw()

# %% [markdown]
# Private attributes

# %% [markdown]
# by adding dubble __

# %%
class Atm:
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.__pin = ''  # constructor is a special function , we will not need to call it once we will make an object of that class the function will automatically run
        self.__balance = 0
        #self.__menu()
                 
        
    def  __menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.__pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self.__balance = user_balance
        
        print('pin created succesfully ')
        
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.__pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.__pin
            print('pin change succesful')
            
        else:
            print('wrong try again')
            
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.__pin:
            print('your balance is',self.__balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.__pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print('withdrawl is succesful balance is',self.__balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')

# %%
obj1 = Atm()

# %%
obj1.create_pin()

# %%
obj1.__balance = 'heehee'

# %%
obj1._Atm__balance = 'ehhehe'

# %%
obj1.user_withdraw()     # it will show error bcoz itentially made changes  in the hidden attribut

# %% [markdown]
# Nothing is truly hidden in python

# %%
class Atm:
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.__pin = ''  
        self.__balance = 0
        #self.__menu()
                  
    def get_balance(self):             # geter
        return self.__balance

   
    def set_balance(self,new_value):      # seter
        if type(new_value) == int:
            self.__balance = new_value
        else:
            print('beta bhot marenge')
        
    def  __menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.__pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self.__balance = user_balance
        
        print('pin created succesfully ')
        
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.__pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.__pin
            print('pin change succesful')
            
        else:
            print('wrong try again')
            
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.__pin:
            print('your balance is',self.__balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.__pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print('withdrawl is succesful balance is',self.__balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')

# %%
obj = Atm()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 obj = Atm()
#
# NameError: name 'Atm' is not defined

# %%
obj.get_balance()

# %%
obj.set_balance('heheehe')

# %% [markdown]
# Collection of objects

# %%
# list of objects 

class person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
p1 = person('amit','male')
p2 = person('ajit','male')
p3 = person('janu','female') 

L = [p1,p2,p3]
    
print(L)         # since in our function we dont have str function we only see the memory location of the objects
# Out:
# [<__main__.person object at 0x000001D376F9DCA0>, <__main__.person object at 0x000001D376F6DF40>, <__main__.person object at 0x000001D376F6C530>]

# %%
for i in L:
    
    print(i.name,i.gender)
# Out:
# amit male
# ajit male
# janu female

# %% [markdown]
# will the objects will be stored inside of a set ????????????

# %%
d ={'p1':p1,'p2':p2,'p3':p3}

for i in d:
    print(i)
    print(d[i].name,d[i].gender)
# Out:
# p1
# amit male
# p2
# ajit male
# p3
# janu female

# %% [markdown]
# Instance and Static variable

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = 0
    self.cid += 1
    #self.menu()

  # utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()

# %%
c2=Atm()

# %%
c3 = Atm()

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 1

# %%
c3.cid  # all the custmers c1,c2,c3 have same value bcoz every time the code is running its initial value becomes 0 and then it get increased by 1 
 
 # this is bcoz c1,c2,c3 are not inter related
# Out:
# 1

# %%
class Atm:
    
    counter = 1 
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.pin = ''  
        self.__balance = 0
        self.cid = Atm.counter                 #name ke aage self likha hai to vo (((instance variable ))) hai object se call hota hai 
        Atm.counter = Atm.counter + 1          # name ke aage class ka name hai to vo (((static variable)))
        # self.cid += 1 
        
        #self.__menu()
                  
    def get_balance(self):             # geter
        return self.__balance

   
    def set_balance(self,new_value):      # seter
        if type(new_value) == int:
            self.__balance = new_value
        else:
            print('beta bhot marenge')
        
    def  __menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.__pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self.__balance = user_balance
        
        print('pin created succesfully ')
        
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.__pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.__pin
            print('pin change succesful')
            
        else:
            print('wrong try again')
            
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.__pin:
            print('your balance is',self.__balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.__pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print('withdrawl is succesful balance is',self.__balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')

# %%
c1 = Atm()

# %%
c2 = Atm()

# %%
c3 = Atm()

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 2

# %%
c3.cid
# Out:
# 3

# %%
Atm.counter
# Out:
# 4

# %%
Atm.counter = 'heehee'

# %%
c4 = Atm()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 c4 = Atm()
#
# Cell In[40], line 10, in Atm.__init__(self)
#       8 self.__balance = 0
#       9 self.cid = Atm.counter                 #name ke aage self likha hai to vo (((instance variable ))) hai object se call hota hai
# ---> 10 Atm.counter = Atm.counter + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ERROR BCOZ OF CHANGES IN CODE WE NEED TO HIDE THE CODE

# %%
class Atm:
    
    __counter = 1 
    
    # constructor(special function)-->superpower-->
    def __init__(self):
        self.pin = ''  
        self.__balance = 0
        self.cid = Atm.__counter                 #name ke aage self likha hai to vo (((instance variable ))) hai object se call hota hai 
        Atm.__counter = Atm.__counter + 1          # name ke aage class ka name hai to vo (((static variable)))
        # self.cid += 1 
        
        #self.__menu()
        
    def get_counter():      # MADE A GETERRRRRRRRRRRRRRRRR WITHOUT SELFFFFFFFF TO acces this geter we need to write class.function 
        return Atm.__counter
    
        
                  
    def get_balance(self):             # geter
        return self.__balance

   
    def set_balance(self,new_value):      # seter
        if type(new_value) == int:
            self.__balance = new_value
        else:
            print('beta bhot marenge')
        
    def  __menu(self):
        user_input = input("""hi how can i help you 
              1. press 1 to create pass 
              2. press 2 to change pass
              3. press 3 to check balance 
              4. press 4 to withdraw
              5. Anything else to exit""" )
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            # change pass
            self.change_pass()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # withdraw
            self.user_withdraw()
    
           
        else:
            exit()
               
    def create_pin(self):
        user_pin = input('enter your pin ')
        self.__pin = user_pin
        
        user_balance = int(input('enter balnce'))    
        self.__balance = user_balance
        
        print('pin created succesfully ')
        
        
    def change_pass(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.__pin:   # let him change the pin 
            new_pin = input('enter new pin')
            new_pin = self.__pin
            print('pin change succesful')
            
        else:
            print('wrong try again')
            
        
    def check_balance(self):    #------>method
        user_pin= input('pin')
        if user_pin == self.__pin:
            print('your balance is',self.__balance)
        else:
            print('wrong pin')
            
            
    def user_withdraw(self):
        enter_pin = input('enter pin')
        if enter_pin == self.__pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print('withdrawl is succesful balance is',self.__balance )
                
            else:
                print('insuffcient amount')
        else:
            print('wrong pin')

# %%
c4 = Atm()
c5 = Atm()

# %%
c4.cid
# Out:
# 5

# %%
c5.cid
# Out:
# 6

# %%
c1 = Atm()

# %%
c1.get_counter()   # the error bcoz it does not take any argument function without self
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 c1.get_counter()   # the error bcoz it does not take any argument function without self
#
# TypeError: Atm.get_counter() takes 0 positional arguments but 1 was given

# %%
Atm.get_counter()
# Out:
# 4
